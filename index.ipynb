# %% [markdown]
# # Pandas Data Cleaning - Cumulative Lab
#
# ## Introduction
# In this lab, we'll make use of everything we've learned about pandas, data cleaning, and exploratory data analysis. In order to complete this lab, you'll have to import, clean, combine, reshape, and visualize data to answer questions provided, as well as your own questions!
#
# ## Objectives
# You will be able to:
# - Practice opening and inspecting the contents of CSVs using pandas dataframes
# - Practice identifying and handling missing values
# - Practice identifying and handling invalid values
# - Practice cleaning text data by removing whitespace and fixing typos
# - Practice joining multiple dataframes

# %% [markdown]
# ## Your Task: Clean the Superheroes Dataset with Pandas
#
# ![LEGO superheroes](images/lego_superheroes.jpg)
#
# Photo by <a href="https://unsplash.com/@yuliamatvienko?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Yulia Matvienko</a> on <a href="/s/photos/superhero?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
# In this lab, we'll work with a version of the comprehensive Superheroes Dataset, which can be found on [Kaggle](https://www.kaggle.com/claudiodavi/superhero-set/data) and was originally scraped from [SuperHeroDb](https://www.superherodb.com/). We have modified the structure and contents of the dataset somewhat for the purposes of this lab.  Note that this data was collected in June 2017, so it may not reflect the most up-to-date superhero lore.
#
# The data is contained in two separate CSV files:
#
# 1. `heroes_information.csv`: each record represents a superhero, with attributes of that superhero (e.g. eye color). Height is measured in centimeters, and weight is measured in pounds.
# 2. `super_hero_powers.csv`: each record represents a superpower, then has True/False values representing whether each superhero has that power
#
# ### Business Understanding
#
# The business questions you have been provided are:
#
# 1. What is the distribution of superheroes by publisher?
# 2. What is the relationship between height and number of superpowers? And does this differ based on gender?
# 3. What are the 5 most common superpowers in Marvel Comics vs. DC Comics?
#
# This lab also simulates something you are likely to encounter at some point or another in your career in data science: someone has given you access to a dataset, as well as a few questions, and has told you to "find something interesting".
#
# So, in addition to completing the basic data cleaning tasks and the aggregation and reshaping tasks needed to answer the provided questions, you will also need to formulate a question of your own and perform any additional cleaning/aggregation/reshaping that is needed to answer it.

# %% [markdown]
# ### Requirements
#
# #### 1. Load the Data with Pandas
#
# Create a dataframes `heroes_df` and `powers_df` that represent the two CSV files. Use pandas methods to inspect the shape and other attributes of these dataframes.
#
# #### 2. Perform Data Cleaning Required to Answer First Question
#
# The first question is: *What is the distribution of superheroes by publisher?*
#
# In order to answer this question, you will need to:
#
# * Identify and handle missing values
# * Identify and handle text data requiring cleaning
#
# #### 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# The second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# In order to answer this question, you will need to:
#
# * Join the dataframes together
# * Identify and handle invalid values
#
# #### 4. Perform Data Aggregation Required to Answer Third Question
#
# The third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# This should not require any additional data cleaning or joining of tables, but it will require some additional aggregation.
#
# #### 5. Formulate and Answer Your Own Question
#
# This part is fairly open-ended. Think of a question that can be answered with the available data, and perform any cleaning or aggregation required to answer that question.

# %% [markdown]
# ## 1. Load the Data with Pandas
#
# In the cell below, we:
#
# * Import and alias `pandas` as `pd`
# * Import and alias `numpy` as `np`
# * Import and alias `seaborn` as `sns`
# * Import and alias `matplotlib.pyplot` as `plt`
# * Set Matplotlib visualizations to display inline in the notebook

# %%
# Run this cell without changes

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Superheroes
#
# In the cell below, load `heroes_information.csv` as `heroes_df`:

# %%
# Your code here
heroes_df = pd.read_csv('heroes_information.csv')
heroes_df.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %% [markdown]
# It looks like that CSV came with an index column, resulting in an extra column called `Unnamed: 0`. We don't need that column, so write code to get rid of it below.
#
# There are two ways to do this:
#
# 1. Re-load with `read_csv`, and specify the parameter `index_col=0`
# 2. Drop the column `Unnamed: 0` with `axis=1`

# %%
# Your code here
heroes_df = pd.read_csv("heroes_information.csv", index_col = 0)
heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %% [markdown]
# The following code checks that the dataframe was loaded correctly.

# %%
# Run this cell without changes

# There should be 734 rows
assert heroes_df.shape[0] == 734

# There should be 10 columns. If this fails, make sure you got rid of
# the extra index column
assert heroes_df.shape[1] == 10

# These should be the columns
assert list(heroes_df.columns) == [
    "name",
    "Gender",
    "Eye color",
    "Race",
    "Hair color",
    "Height",
    "Publisher",
    "Skin color",
    "Alignment",
    "Weight",
]

# %% [markdown]
# Now you want to get familiar with the data.  This step includes:
#
# * Understanding the dimensionality of your dataset
# * Investigating what type of data it contains, and the data types used to store it
# * Discovering how missing values are encoded, and how many there are
# * Getting a feel for what information it does and doesn't contain
#
# In the cell below, inspect the overall shape of the dataframe:

# %%
# Your code here
heroes_df.shape
# Out:
# (734, 10)

# %% [markdown]
# Now let's look at the info printout:

# %%
# Run this cell without changes
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 734 entries, 0 to 733
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        734 non-null    object
#  1   Gender      734 non-null    object
#  2   Eye color   734 non-null    object
#  3   Race        734 non-null    object
#  4   Hair color  734 non-null    object
#  5   Height      734 non-null    float64
#  6   Publisher   719 non-null    object
#  7   Skin color  734 non-null    object
#  8   Alignment   734 non-null    object
#  9   Weight      732 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 63.1+ KB

# %%
heroes_df.isna().sum()
# Out:
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         2
# dtype: int64

# %% [markdown]
# In the cell below, interpret that information. Do the data types line up with what we expect? Are there any missing values?

# %%
# Replace None with appropriate text
"""
The datatypes lineup as I expected. The two columns, weight and height, are both floats showing the numerical variables
and everything else is a categorical variable. We have null values in the weight and publisher columns that will need
to get fixed. Also, looking at the datafrane it appears skin color has a lot of placeholder or null values shown by
the character '-'. I dont think skin color will really relate to any of our questions so this column can potentially 
be dropped all together as it wont affect any results. 
"""
# Out:
# "\nThe datatypes lineup as I expected. The two columns, weight and height, are both floats showing the numerical variables\nand everything else is a categorical variable. We have null values in the weight and publisher columns that will need\nto get fixed. Also, looking at the datafrane it appears skin color has a lot of placeholder or null values shown by\nthe character '-'. I dont think skin color will really relate to any of our questions so this column can potentially \nbe dropped all together as it wont affect any results. \n"

# %% [markdown]
# ### Superpowers
#
# Now, repeat the same process with `super_hero_powers.csv`. Name the dataframe `powers_df`. This time, make sure you use `index_col=0` when opening the CSV because the index contains important information.

# %%
# Your code here (create more cells as needed)
powers_df = pd.read_csv('super_hero_powers.csv', index_col = 0)

# %% [markdown]
# The following code will check if it was loaded correctly:

# %%
# Run this cell without changes

# There should be 167 rows, 667 columns
assert powers_df.shape == (167, 667)

# The first column should be '3-D Man'
assert powers_df.columns[0] == "3-D Man"

# The last column should be 'Zoom'
assert powers_df.columns[-1] == "Zoom"

# The first index should be 'Agility'
assert powers_df.index[0] == "Agility"

# The last index should be 'Omniscient'
assert powers_df.index[-1] == "Omniscient"

# %%
powers_df.head()
# Out:
#                        3-D Man  A-Bomb  Abe Sapien  Abin Sur  Abomination  \
# Agility                   True   False        True     False        False
# Accelerated Healing      False    True        True     False         True
# Lantern Power Ring       False   False       False      True        False
# Dimensional Awareness    False   False       False     False        False
# Cold Resistance          False   False        True     False        False
#
#                        Abraxas  Absorbing Man  Adam Monroe  Adam Strange  \
# Agility                  False          False        False         False
# Accelerated Healing      False          False         True         False
# Lantern Power Ring       False          False        False         False
# Dimensional Awareness     True          False        False         False
# Cold Resistance          False           True        False         False
#
#                        Agent Bob  ...  Wonder Man  Wonder Woman   X-23  X-Man  \
# Agility                    False  ...       False         False   True  False
# Accelerated Healing        False  ...       False          True   True  False
# Lantern Power Ring         False  ...       False         False  False  False
# Dimensional Awareness      False  ...       False         False  False  False
# Cold Resistance            False  ...       False         False  False  False
#
#                        Yellowjacket  Yellowjacket II   Ymir   Yoda  Zatanna  \
# Agility                       False            False  False   True    False
# Accelerated Healing           False            False  False  False    False
# Lantern Power Ring            False            False  False  False    False
# Dimensional Awareness         False            False  False  False    False
# Cold Resistance               False            False   True  False    False
#
#                         Zoom
# Agility                False
# Accelerated Healing    False
# Lantern Power Ring     False
# Dimensional Awareness  False
# Cold Resistance        False
#
# [5 rows x 667 columns]

# %% [markdown]
# ## 2. Perform Data Cleaning Required to Answer First Question
#
# Recall that the first question is: *What is the distribution of superheroes by publisher?*
#
# To answer this question, we will only need to use `heroes_df`, which contains the `Publisher` column.
#
# ### Identifying and Handling Missing Values
#
# As you likely noted above, the `Publisher` column is missing some values. Let's take a look at some samples with and without missing publisher values:

# %%
# Run this cell without changes
has_publisher_sample = heroes_df[heroes_df["Publisher"].notna()].sample(
    5, random_state=1
)
has_publisher_sample
# Out:
#            name  Gender Eye color   Race        Hair color  Height  \
# 60      Banshee    Male     green  Human  Strawberry Blond   183.0
# 61       Bantam    Male     brown      -             Black   165.0
# 219  DL Hawkins    Male         -      -                 -   -99.0
# 650       Synch    Male     brown      -             Black   180.0
# 8      Agent 13  Female      blue      -             Blond   173.0
#
#          Publisher Skin color Alignment  Weight
# 60   Marvel Comics          -      good    77.0
# 61   Marvel Comics          -      good    54.0
# 219   NBC - Heroes          -      good   -99.0
# 650  Marvel Comics          -      good    74.0
# 8    Marvel Comics          -      good    61.0

# %%
# Run this cell without changes
missing_publisher_sample = heroes_df[heroes_df["Publisher"].isna()].sample(
    5, random_state=1
)
missing_publisher_sample
# Out:
#                  name  Gender Eye color    Race Hair color  Height Publisher  \
# 175      Chuck Norris    Male         -       -          -   178.0       NaN
# 286          Godzilla       -         -   Kaiju          -   108.0       NaN
# 263      Flash Gordon    Male         -       -          -   -99.0       NaN
# 138        Brundlefly    Male         -  Mutant          -   193.0       NaN
# 381  Katniss Everdeen  Female         -   Human          -   -99.0       NaN
#
#     Skin color Alignment  Weight
# 175          -      good   -99.0
# 286       grey       bad     NaN
# 263          -      good   -99.0
# 138          -         -   -99.0
# 381          -      good   -99.0

# %% [markdown]
# What do we want to do about these missing values?
#
# Recall that there are two general strategies for dealing with missing values:
#
# 1. Fill in missing values (either using another value from the column, e.g. the mean or mode, or using some other value like "Unknown")
# 2. Drop rows with missing values
#
# Write your answer below, and explain how it relates to the information we have:

# %%
# Replace None with appropriate text
"""
There are over 700 rows and only 15 missing for this column. I believe removing the rows will null values to be the 
best solution. It is not be a significant amount of data points to affect our results. 
Additionally,if you were to replace the nulls with, for example, the mode publisher, based on the population that 
would be interested in these results, they would quickly realize when you list a superhero under a completely 
different publisher and this might even upset them. They would immediately deem your results as 
inaccurate if they saw just one instance of this (In my opinion, I would). 
"""
# Out:
# '\nThere are over 700 rows and only 15 missing for this column. I believe removing the rows will null values to be the \nbest solution. It is not be a significant amount of data points to affect our results. \nAdditionally,if you were to replace the nulls with, for example, the mode publisher, based on the population that \nwould be interested in these results, they would quickly realize when you list a superhero under a completely \ndifferent publisher and this might even upset them. They would immediately deem your results as \ninaccurate if they saw just one instance of this (In my opinion, I would). \n'

# %% [markdown]
# Now, implement the strategy to drop rows with missing values using code. (You can also check the solution branch for the answer to the question above if you're really not sure.)

# %%
# Your code here
heroes_df = heroes_df.dropna(axis=0, subset=['Publisher'])

# %% [markdown]
# Now there should be no missing values in the publisher column:

# %%
# Run this cell without changes
assert heroes_df["Publisher"].isna().sum() == 0

# %% [markdown]
# ### Identifying and Handling Text Data Requiring Cleaning
#
# The overall field of natural language processing (NLP) is quite broad, and we're not going to get into any advanced text processing, but it's useful to be able to clean up minor issues in text data.
#
# Let's take a look at the counts of heroes grouped by publisher:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Marvel Comics        379
# DC Comics            212
# NBC - Heroes          19
# Dark Horse Comics     18
# Image Comics          14
# George Lucas          14
# Marvel                 9
# HarperCollins          6
# Star Trek              6
# Team Epic TV           5
# SyFy                   5
# IDW Publishing         4
# Icon Comics            4
# ABC Studios            4
# Shueisha               4
#  DC Comics             3
# Wildstorm              3
# Sony Pictures          2
# South Park             1
# Hanna-Barbera          1
# Microsoft              1
# Titan Books            1
# Rebellion              1
# Universal Studios      1
# J. R. R. Tolkien       1
# J. K. Rowling          1
# Name: Publisher, dtype: int64

# %% [markdown]
# There are two cases where we appear to have data entry issues, and publishers that should be encoded the same have not been. In other words, there are four categories present that really should be counted as two categories (and you do not need specific comic book knowledge to be able to identify them).
#
# Identify those two cases below:

# %%
# Replace None with appropriate text
"""
The first one that caught my eye was DC Comics with a space at the beginning and another DC Comics with no space.
The second one appears to be Marvel and Marvel Comics. These are also one and the same. 
"""
# Out:
# '\nThe first one that caught my eye was DC Comics with a space at the beginning and another DC Comics with no space.\nThe second one appears to be Marvel and Marvel Comics. These are also one and the same. \n'

# %% [markdown]
# Now, write some code to handle these cases. If you're not sure where to start, look at the pandas documentation for [replacing values](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.replace.html) and [stripping off whitespace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.strip.html).

# %%
type(heroes_df['Publisher'])
# Out:
# pandas.core.series.Series

# %%
# Your code here
heroes_df['Publisher'] = heroes_df['Publisher'].replace({'Marvel': 'Marvel Comics', " DC Comics": "DC Comics" })

# %% [markdown]
# Check your work below:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Marvel Comics        388
# DC Comics            215
# NBC - Heroes          19
# Dark Horse Comics     18
# Image Comics          14
# George Lucas          14
# HarperCollins          6
# Star Trek              6
# Team Epic TV           5
# SyFy                   5
# ABC Studios            4
# Icon Comics            4
# Shueisha               4
# IDW Publishing         4
# Wildstorm              3
# Sony Pictures          2
# Titan Books            1
# Rebellion              1
# Universal Studios      1
# South Park             1
# Hanna-Barbera          1
# Microsoft              1
# J. R. R. Tolkien       1
# J. K. Rowling          1
# Name: Publisher, dtype: int64

# %% [markdown]
# ### Answering the Question
#
# Now we should be able to answer *What is the distribution of superheroes by publisher?*
#
# If your data cleaning was done correctly, this code should work without any further changes:

# %%
# Run this cell without changes

# Set up plots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))

# Create variables for easier reuse
value_counts = heroes_df["Publisher"].value_counts()
top_5_counts = value_counts.iloc[:5]

# Plot data
ax1.bar(value_counts.index, value_counts.values)
ax2.bar(top_5_counts.index, top_5_counts.values)

# Customize appearance
ax1.tick_params(axis="x", labelrotation=90)
ax2.tick_params(axis="x", labelrotation=45)
ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Distribution of Superheroes by Publisher")
ax2.set_title("Top 5 Publishers by Count of Superheroes");

# %% [markdown]
# ## 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# Recall that the second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# Unlike the previous question, we won't be able to answer this with just `heroes_df`, since information about height is contained in `heroes_df`, while information about superpowers is contained in `powers_df`.
#
# ### Joining the Dataframes Together
#
# First, identify the shared key between `heroes_df` and `powers_df`. (Shared key meaning, the values you want to join on.) Let's look at them again:

# %%
# Run this cell without changes
heroes_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight
# 0     203.0      Marvel Comics          -      good   441.0
# 1     191.0  Dark Horse Comics       blue      good    65.0
# 2     185.0          DC Comics        red      good    90.0
# 3     203.0      Marvel Comics          -       bad   441.0
# 4     -99.0      Marvel Comics          -       bad   -99.0
# ..      ...                ...        ...       ...     ...
# 729   165.0      Marvel Comics          -      good    52.0
# 730   304.8      Marvel Comics      white      good   -99.0
# 731    66.0       George Lucas      green      good    17.0
# 732   170.0          DC Comics          -      good    57.0
# 733   185.0          DC Comics          -       bad    81.0
#
# [719 rows x 10 columns]

# %%
# Run this cell without changes
powers_df
# Out:
#                        3-D Man  A-Bomb  Abe Sapien  Abin Sur  Abomination  \
# Agility                   True   False        True     False        False
# Accelerated Healing      False    True        True     False         True
# Lantern Power Ring       False   False       False      True        False
# Dimensional Awareness    False   False       False     False        False
# Cold Resistance          False   False        True     False        False
# ...                        ...     ...         ...       ...          ...
# Phoenix Force            False   False       False     False        False
# Molecular Dissipation    False   False       False     False        False
# Vision - Cryo            False   False       False     False        False
# Omnipresent              False   False       False     False        False
# Omniscient               False   False       False     False        False
#
#                        Abraxas  Absorbing Man  Adam Monroe  Adam Strange  \
# Agility                  False          False        False         False
# Accelerated Healing      False          False         True         False
# Lantern Power Ring       False          False        False         False
# Dimensional Awareness     True          False        False         False
# Cold Resistance          False           True        False         False
# ...                        ...            ...          ...           ...
# Phoenix Force            False          False        False         False
# Molecular Dissipation    False          False        False         False
# Vision - Cryo            False          False        False         False
# Omnipresent              False          False        False         False
# Omniscient               False          False        False         False
#
#                        Agent Bob  ...  Wonder Man  Wonder Woman   X-23  X-Man  \
# Agility                    False  ...       False         False   True  False
# Accelerated Healing        False  ...       False          True   True  False
# Lantern Power Ring         False  ...       False         False  False  False
# Dimensional Awareness      False  ...       False         False  False  False
# Cold Resistance            False  ...       False         False  False  False
# ...                          ...  ...         ...           ...    ...    ...
# Phoenix Force              False  ...       False         False  False  False
# Molecular Dissipation      False  ...       False         False  False  False
# Vision - Cryo              False  ...       False         False  False  False
# Omnipresent                False  ...       False         False  False  False
# Omniscient                 False  ...       False         False  False  False
#
#                        Yellowjacket  Yellowjacket II   Ymir   Yoda  Zatanna  \
# Agility                       False            False  False   True    False
# Accelerated Healing           False            False  False  False    False
# Lantern Power Ring            False            False  False  False    False
# Dimensional Awareness         False            False  False  False    False
# Cold Resistance               False            False   True  False    False
# ...                             ...              ...    ...    ...      ...
# Phoenix Force                 False            False  False  False    False
# Molecular Dissipation         False            False  False  False    False
# Vision - Cryo                 False            False  False  False    False
# Omnipresent                   False            False  False  False    False
# Omniscient                    False            False  False  False    False
#
#                         Zoom
# Agility                False
# Accelerated Healing    False
# Lantern Power Ring     False
# Dimensional Awareness  False
# Cold Resistance        False
# ...                      ...
# Phoenix Force          False
# Molecular Dissipation  False
# Vision - Cryo          False
# Omnipresent            False
# Omniscient             False
#
# [167 rows x 667 columns]

# %% [markdown]
# In the cell below, identify the shared key, and your strategy for joining the data (e.g. what will one record represent after you join, will you do a left/right/inner/outer join):

# %%
# Replace None with appropriate text
"""
The shared keys between the two dataframes is the superhero name. As far as the join, for the powers_df we want the
name of the superhero and the number of superpowers (create a df of that count) then we can join the two together. 
The number of rows present in names for heroes_df is greater than the amount of columns in power_df and some that arent present in both.
Therefore, I just want to include what is present in both datasets so i would do an inner join. The difficulty will 
be that the names are columns in thepowers_df, where as the names are listed in rows in the heroes_df. 
"""
# Out:
# '\nThe shared keys between the two dataframes is the superhero name. As far as the join, for the powers_df we want the\nname of the superhero and the number of superpowers (create a df of that count) then we can join the two together. \nThe number of rows present in names for heroes_df is greater than the amount of columns in power_df and some that arent present in both.\nTherefore, I just want to include what is present in both datasets so i would do an inner join. The difficulty will \nbe that the names are columns in thepowers_df, where as the names are listed in rows in the heroes_df. \n'

# %% [markdown]
# In the cell below, create a new dataframe called `heroes_and_powers_df` that contains the joined data. You can look at the above answer in the solution branch if you're not sure where to start.
#
# ***Hint:*** Note that the `.join` method requires that the two dataframes share an index ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html)) whereas the `.merge` method can join using any columns ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html)). It is up to you which one you want to use.

# %%
# Your code here (create more cells as needed)
powers_df_transposed = powers_df.T
powers_df_transposed
# Out:
#                  Agility  Accelerated Healing  Lantern Power Ring  \
# 3-D Man             True                False               False
# A-Bomb             False                 True               False
# Abe Sapien          True                 True               False
# Abin Sur           False                False                True
# Abomination        False                 True               False
# ...                  ...                  ...                 ...
# Yellowjacket II    False                False               False
# Ymir               False                False               False
# Yoda                True                False               False
# Zatanna            False                False               False
# Zoom               False                False               False
#
#                  Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 3-D Man                          False            False       False    False
# A-Bomb                           False            False        True    False
# Abe Sapien                       False             True        True    False
# Abin Sur                         False            False       False    False
# Abomination                      False            False       False    False
# ...                                ...              ...         ...      ...
# Yellowjacket II                  False            False       False    False
# Ymir                             False             True        True    False
# Yoda                             False            False       False     True
# Zatanna                          False            False       False    False
# Zoom                             False            False       False    False
#
#                  Energy Absorption  Flight  Danger Sense  ...  Web Creation  \
# 3-D Man                      False   False         False  ...         False
# A-Bomb                       False   False         False  ...         False
# Abe Sapien                   False   False         False  ...         False
# Abin Sur                     False   False         False  ...         False
# Abomination                  False   False         False  ...         False
# ...                            ...     ...           ...  ...           ...
# Yellowjacket II              False    True         False  ...         False
# Ymir                         False   False         False  ...         False
# Yoda                         False   False          True  ...         False
# Zatanna                      False   False         False  ...         False
# Zoom                         False   False         False  ...         False
#
#                  Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 3-D Man                    False       False             False        False
# A-Bomb                     False       False             False        False
# Abe Sapien                 False       False             False        False
# Abin Sur                   False       False             False        False
# Abomination                False       False             False        False
# ...                          ...         ...               ...          ...
# Yellowjacket II            False       False             False        False
# Ymir                       False       False             False        False
# Yoda                       False       False             False        False
# Zatanna                    False       False             False        False
# Zoom                       False       False             False        False
#
#                  Phoenix Force  Molecular Dissipation  Vision - Cryo  \
# 3-D Man                  False                  False          False
# A-Bomb                   False                  False          False
# Abe Sapien               False                  False          False
# Abin Sur                 False                  False          False
# Abomination              False                  False          False
# ...                        ...                    ...            ...
# Yellowjacket II          False                  False          False
# Ymir                     False                  False          False
# Yoda                     False                  False          False
# Zatanna                  False                  False          False
# Zoom                     False                  False          False
#
#                  Omnipresent  Omniscient
# 3-D Man                False       False
# A-Bomb                 False       False
# Abe Sapien             False       False
# Abin Sur               False       False
# Abomination            False       False
# ...                      ...         ...
# Yellowjacket II        False       False
# Ymir                   False       False
# Yoda                   False       False
# Zatanna                False       False
# Zoom                   False       False
#
# [667 rows x 167 columns]

# %%
powers_df_transposed.index.name = "name"
powers_df_transposed.reset_index(inplace=True)
powers_df_transposed
# Out:
#                 name  Agility  Accelerated Healing  Lantern Power Ring  \
# 0            3-D Man     True                False               False
# 1             A-Bomb    False                 True               False
# 2         Abe Sapien     True                 True               False
# 3           Abin Sur    False                False                True
# 4        Abomination    False                 True               False
# ..               ...      ...                  ...                 ...
# 662  Yellowjacket II    False                False               False
# 663             Ymir    False                False               False
# 664             Yoda     True                False               False
# 665          Zatanna    False                False               False
# 666             Zoom    False                False               False
#
#      Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                    False            False       False    False
# 1                    False            False        True    False
# 2                    False             True        True    False
# 3                    False            False       False    False
# 4                    False            False       False    False
# ..                     ...              ...         ...      ...
# 662                  False            False       False    False
# 663                  False             True        True    False
# 664                  False            False       False     True
# 665                  False            False       False    False
# 666                  False            False       False    False
#
#      Energy Absorption  Flight  ...  Web Creation  Reality Warping  \
# 0                False   False  ...         False            False
# 1                False   False  ...         False            False
# 2                False   False  ...         False            False
# 3                False   False  ...         False            False
# 4                False   False  ...         False            False
# ..                 ...     ...  ...           ...              ...
# 662              False    True  ...         False            False
# 663              False   False  ...         False            False
# 664              False   False  ...         False            False
# 665              False   False  ...         False            False
# 666              False   False  ...         False            False
#
#      Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# 0         False             False        False          False
# 1         False             False        False          False
# 2         False             False        False          False
# 3         False             False        False          False
# 4         False             False        False          False
# ..          ...               ...          ...            ...
# 662       False             False        False          False
# 663       False             False        False          False
# 664       False             False        False          False
# 665       False             False        False          False
# 666       False             False        False          False
#
#      Molecular Dissipation  Vision - Cryo  Omnipresent  Omniscient
# 0                    False          False        False       False
# 1                    False          False        False       False
# 2                    False          False        False       False
# 3                    False          False        False       False
# 4                    False          False        False       False
# ..                     ...            ...          ...         ...
# 662                  False          False        False       False
# 663                  False          False        False       False
# 664                  False          False        False       False
# 665                  False          False        False       False
# 666                  False          False        False       False
#
# [667 rows x 168 columns]

# %%
heroes_df.merge(powers_df_transposed, on='name', how='inner')
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 642  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 643             Ymir    Male     white        Frost Giant           No Hair
# 644             Yoda    Male     brown     Yoda's species             White
# 645          Zatanna  Female      blue              Human             Black
# 646             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  ...  \
# 0     203.0      Marvel Comics          -      good   441.0  ...
# 1     191.0  Dark Horse Comics       blue      good    65.0  ...
# 2     185.0          DC Comics        red      good    90.0  ...
# 3     203.0      Marvel Comics          -       bad   441.0  ...
# 4     -99.0      Marvel Comics          -       bad   -99.0  ...
# ..      ...                ...        ...       ...     ...  ...
# 642   165.0      Marvel Comics          -      good    52.0  ...
# 643   304.8      Marvel Comics      white      good   -99.0  ...
# 644    66.0       George Lucas      green      good    17.0  ...
# 645   170.0          DC Comics          -      good    57.0  ...
# 646   185.0          DC Comics          -       bad    81.0  ...
#
#      Web Creation  Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0           False            False       False             False        False
# 1           False            False       False             False        False
# 2           False            False       False             False        False
# 3           False            False       False             False        False
# 4           False            False       False             False        False
# ..            ...              ...         ...               ...          ...
# 642         False            False       False             False        False
# 643         False            False       False             False        False
# 644         False            False       False             False        False
# 645         False            False       False             False        False
# 646         False            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# ..             ...                    ...            ...          ...
# 642          False                  False          False        False
# 643          False                  False          False        False
# 644          False                  False          False        False
# 645          False                  False          False        False
# 646          False                  False          False        False
#
#      Omniscient
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 642       False
# 643       False
# 644       False
# 645       False
# 646       False
#
# [647 rows x 177 columns]

# %%
heroes_and_powers_df = heroes_df.merge(powers_df_transposed, on="name", how="inner")

# %% [markdown]
# Run the code below to check your work:

# %%
# Run this cell without changes

# Confirms you have created a DataFrame with the specified name
assert type(heroes_and_powers_df) == pd.DataFrame

# Confirms you have the right number of rows
assert heroes_and_powers_df.shape[0] == 647

# Confirms you have the necessary columns
# (If you modified the value of powers_df along the way, you might need to
# modify this test. We are checking that all of the powers are present as
# columns.)
assert [power in heroes_and_powers_df.columns for power in powers_df.index]
# (If you modified the value of heroes_df along the way, you might need to
# modify this as well. We are checking that all of the attribute columns from
# heroes_df are present as columns in the joined df)
assert [attribute in heroes_and_powers_df.columns for attribute in heroes_df.columns]

# %% [markdown]
# Now that we have created a joined dataframe, we can aggregate the number of superpowers by superhero. This code is written for you:

# %%
# Run this cell without changes

# Note: we can use sum() with True and False values and they will
# automatically be cast to 1s and 0s
heroes_and_powers_df["Power Count"] = sum(
    [heroes_and_powers_df[power_name] for power_name in powers_df.index]
)
heroes_and_powers_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 642  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 643             Ymir    Male     white        Frost Giant           No Hair
# 644             Yoda    Male     brown     Yoda's species             White
# 645          Zatanna  Female      blue              Human             Black
# 646             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  ...  \
# 0     203.0      Marvel Comics          -      good   441.0  ...
# 1     191.0  Dark Horse Comics       blue      good    65.0  ...
# 2     185.0          DC Comics        red      good    90.0  ...
# 3     203.0      Marvel Comics          -       bad   441.0  ...
# 4     -99.0      Marvel Comics          -       bad   -99.0  ...
# ..      ...                ...        ...       ...     ...  ...
# 642   165.0      Marvel Comics          -      good    52.0  ...
# 643   304.8      Marvel Comics      white      good   -99.0  ...
# 644    66.0       George Lucas      green      good    17.0  ...
# 645   170.0          DC Comics          -      good    57.0  ...
# 646   185.0          DC Comics          -       bad    81.0  ...
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 4              False       False             False        False
# ..               ...         ...               ...          ...
# 642            False       False             False        False
# 643            False       False             False        False
# 644            False       False             False        False
# 645            False       False             False        False
# 646            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# ..             ...                    ...            ...          ...
# 642          False                  False          False        False
# 643          False                  False          False        False
# 644          False                  False          False        False
# 645          False                  False          False        False
# 646          False                  False          False        False
#
#      Omniscient  Power Count
# 0         False            7
# 1         False           16
# 2         False            1
# 3         False            8
# 4         False           14
# ..          ...          ...
# 642       False            3
# 643       False            6
# 644       False           19
# 645       False            8
# 646       False            4
#
# [647 rows x 178 columns]

# %%
powers_df.index
# Out:
# Index(['Agility', 'Accelerated Healing', 'Lantern Power Ring',
#        'Dimensional Awareness', 'Cold Resistance', 'Durability', 'Stealth',
#        'Energy Absorption', 'Flight', 'Danger Sense',
#        ...
#        'Web Creation', 'Reality Warping', 'Odin Force', 'Symbiote Costume',
#        'Speed Force', 'Phoenix Force', 'Molecular Dissipation',
#        'Vision - Cryo', 'Omnipresent', 'Omniscient'],
#       dtype='object', length=167)

# %%
[heroes_and_powers_df[power_name] for power_name in powers_df.index]
# Out:
# [0      False
#  1       True
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644     True
#  645    False
#  646    False
#  Name: Agility, Length: 647, dtype: bool,
#  0       True
#  1       True
#  2      False
#  3       True
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Accelerated Healing, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2       True
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Lantern Power Ring, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4       True
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Dimensional Awareness, Length: 647, dtype: bool,
#  0      False
#  1       True
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643     True
#  644    False
#  645    False
#  646    False
#  Name: Cold Resistance, Length: 647, dtype: bool,
#  0       True
#  1       True
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643     True
#  644    False
#  645    False
#  646    False
#  Name: Durability, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644     True
#  645    False
#  646    False
#  Name: Stealth, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Energy Absorption, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4       True
#         ...
#  642     True
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Flight, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644     True
#  645    False
#  646    False
#  Name: Danger Sense, Length: 647, dtype: bool,
#  0      False
#  1       True
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Underwater breathing, Length: 647, dtype: bool,
#  0      False
#  1       True
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644     True
#  645    False
#  646    False
#  Name: Marksmanship, Length: 647, dtype: bool,
#  0      False
#  1       True
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644     True
#  645    False
#  646    False
#  Name: Weapons Master, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Power Augmentation, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Animal Attributes, Length: 647, dtype: bool,
#  0       True
#  1       True
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643     True
#  644     True
#  645    False
#  646    False
#  Name: Longevity, Length: 647, dtype: bool,
#  0      False
#  1       True
#  2      False
#  3       True
#  4       True
#         ...
#  642    False
#  643    False
#  644     True
#  645    False
#  646    False
#  Name: Intelligence, Length: 647, dtype: bool,
#  0       True
#  1       True
#  2      False
#  3       True
#  4       True
#         ...
#  642    False
#  643     True
#  644    False
#  645    False
#  646    False
#  Name: Super Strength, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643     True
#  644    False
#  645     True
#  646    False
#  Name: Cryokinesis, Length: 647, dtype: bool,
#  0      False
#  1       True
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644     True
#  645     True
#  646    False
#  Name: Telepathy, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Energy Armor, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642     True
#  643    False
#  644     True
#  645    False
#  646    False
#  Name: Energy Blasts, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Duplication, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4       True
#         ...
#  642     True
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Size Changing, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Density Control, Length: 647, dtype: bool,
#  0       True
#  1       True
#  2      False
#  3       True
#  4      False
#         ...
#  642    False
#  643    False
#  644     True
#  645    False
#  646    False
#  Name: Stamina, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Astral Travel, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Audio Control, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Dexterity, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Omnitrix, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3       True
#  4       True
#         ...
#  642    False
#  643    False
#  644     True
#  645    False
#  646     True
#  Name: Super Speed, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Possession, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Animal Oriented Powers, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Weapon-based Powers, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Electrokinesis, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Darkforce Manipulation, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Death Touch, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4       True
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Teleportation, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Enhanced Senses, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644     True
#  645    False
#  646    False
#  Name: Telekinesis, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Energy Beams, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4       True
#         ...
#  642    False
#  643    False
#  644    False
#  645     True
#  646    False
#  Name: Magic, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Hyperkinesis, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644     True
#  645    False
#  646    False
#  Name: Jump, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Clairvoyance, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4       True
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Dimensional Travel, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Power Sense, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Shapeshifting, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Peak Human Condition, Length: 647, dtype: bool,
#  0      False
#  1       True
#  2      False
#  3      False
#  4       True
#         ...
#  642    False
#  643     True
#  644    False
#  645    False
#  646    False
#  Name: Immortality, Length: 647, dtype: bool,
#  0       True
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Camouflage, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Element Control, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Phasing, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Astral Projection, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Electrical Transport, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645     True
#  646    False
#  Name: Fire Control, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Projection, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Summoning, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Enhanced Memory, Length: 647, dtype: bool,
#  0      False
#  1       True
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644     True
#  645    False
#  646    False
#  Name: Reflexes, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3       True
#  4       True
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Invulnerability, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Energy Constructs, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644     True
#  645    False
#  646    False
#  Name: Force Fields, Length: 647, dtype: bool,
#  0       True
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Self-Sustenance, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Anti-Gravity, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644     True
#  645    False
#  646    False
#  Name: Empathy, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Power Nullifier, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Radiation Control, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Psionic Powers, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Elasticity, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Substance Secretion, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Elemental Transmogrification, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Technopath/Cyberpath, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Photographic Reflexes, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Seismic Power, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3       True
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Animation, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644     True
#  645    False
#  646    False
#  Name: Precognition, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Mind Control, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Fire Resistance, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Power Absorption, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Enhanced Hearing, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Nova Force, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Insanity, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Hypnokinesis, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Animal Control, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Natural Armor, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646     True
#  Name: Intangibility, Length: 647, dtype: bool,
#  0      False
#  1       True
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Enhanced Sight, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4       True
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Molecular Manipulation, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Heat Generation, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Adaptation, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Gliding, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Power Suit, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Mind Blast, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645     True
#  646    False
#  Name: Probability Manipulation, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Gravity Control, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Regeneration, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Light Control, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Echolocation, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Levitation, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Toxin and Disease Control, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Banish, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4       True
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Energy Manipulation, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Heat Resistance, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Natural Weapons, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646     True
#  Name: Time Travel, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Enhanced Smell, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Illusions, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Thirstokinesis, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Hair Manipulation, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Illumination, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Omnipotent, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644     True
#  645    False
#  646    False
#  Name: Cloaking, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Changing Armor, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4       True
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Power Cosmic, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Biokinesis, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645     True
#  646    False
#  Name: Water Control, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Radiation Immunity, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Vision - Telescopic, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Toxin and Disease Resistance, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Spatial Awareness, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Energy Resistance, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Telepathy Resistance, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Molecular Combustion, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Omnilingualism, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Portal Creation, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Magnetism, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Mind Control Resistance, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Plant Control, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Sonar, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Sonic Scream, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646     True
#  Name: Time Manipulation, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Enhanced Touch, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Magic Resistance, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Invisibility, Length: 647, dtype: bool,
#  0      False
#  1       True
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Sub-Mariner, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Radiation Absorption, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Intuitive aptitude, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Vision - Microscopic, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Melting, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Wind Control, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3       True
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Super Breath, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Wallcrawling, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Vision - Night, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Vision - Infrared, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Grim Reaping, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Matter Absorption, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644     True
#  645    False
#  646    False
#  Name: The Force, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Resurrection, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645     True
#  646    False
#  Name: Terrakinesis, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Vision - Heat, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Vitakinesis, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Radar Sense, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Qwardian Power Ring, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645     True
#  646    False
#  Name: Weather Control, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Vision - X-Ray, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Vision - Thermal, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Web Creation, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Reality Warping, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Odin Force, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Symbiote Costume, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Speed Force, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Phoenix Force, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Molecular Dissipation, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Vision - Cryo, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Omnipresent, Length: 647, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  642    False
#  643    False
#  644    False
#  645    False
#  646    False
#  Name: Omniscient, Length: 647, dtype: bool]

# %% [markdown]
# ### Answering the Question
#
# Now we can plot the height vs. the count of powers:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=heroes_and_powers_df["Height"], y=heroes_and_powers_df["Power Count"], alpha=0.3
)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Hmm...what is that stack of values off below zero? What is a "negative" height?

# %% [markdown]
# ### Identifying and Handling Invalid values
#
# One of the trickier tasks in data cleaning is identifying invalid or impossible values. In these cases, you have to apply your domain knowledge rather than any particular computational technique. For example, if you were looking at data containing dates of past home sales, and one of those dates was 100 years in the future, pandas wouldn't flag that as an issue, but you as a data scientist should be able to identify it.
#
# In this case, we are looking at heights, which are 1-dimensional, positive numbers. In theory we could have a very tiny height close to 0 cm because the hero is microscopic, but it does not make sense that we would have a height below zero.
#
# Let's take a look at a sample of those negative heights:

# %%
# Run this cell without changes
heroes_and_powers_df[heroes_and_powers_df["Height"] < 0].sample(5, random_state=1)
# Out:
#                  name  Gender Eye color   Race        Hair color  Height  \
# 150         Chameleon    Male         -      -                 -   -99.0
# 163  Crimson Crusader    Male      blue      -  Strawberry Blond   -99.0
# 364              Luna  Female         -  Human                 -   -99.0
# 315         JJ Powell    Male         -      -                 -   -99.0
# 630         Weapon XI    Male         -      -                 -   -99.0
#
#          Publisher Skin color Alignment  Weight  ...  Reality Warping  \
# 150      DC Comics          -       bad   -99.0  ...            False
# 163  Marvel Comics          -      good   -99.0  ...            False
# 364  Marvel Comics          -      good   -99.0  ...            False
# 315    ABC Studios          -      good   -99.0  ...            False
# 630  Marvel Comics          -       bad   -99.0  ...            False
#
#      Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# 150       False             False        False          False
# 163       False             False        False          False
# 364       False             False        False          False
# 315       False             False        False          False
# 630       False             False        False          False
#
#      Molecular Dissipation  Vision - Cryo  Omnipresent  Omniscient  \
# 150                  False          False        False       False
# 163                  False          False        False       False
# 364                  False          False        False       False
# 315                  False          False        False       False
# 630                  False          False        False       False
#
#      Power Count
# 150            1
# 163            4
# 364            1
# 315            1
# 630            7
#
# [5 rows x 178 columns]

# %% [markdown]
# It looks like not only are those heights negative, those weights are negative also, and all of them are set to exactly -99.0.
#
# It seems like this data source probably filled in -99.0 as the height or weight whenever it was unknown, instead of just leaving it as NaN.
#
# Depending on the purpose of the analysis, maybe this would be a useful piece of information, but for our current question, let's go ahead and drop the records where the height is -99.0. We'll make a new temporary dataframe to make sure we don't accidentally delete anything that will be needed in a future question.

# %%
# Run this cell without changes
question_2_df = heroes_and_powers_df[heroes_and_powers_df["Height"] != -99.0].copy()
question_2_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 5      Absorbing Man    Male      blue              Human           No Hair
# ..               ...     ...       ...                ...               ...
# 642  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 643             Ymir    Male     white        Frost Giant           No Hair
# 644             Yoda    Male     brown     Yoda's species             White
# 645          Zatanna  Female      blue              Human             Black
# 646             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  ...  \
# 0     203.0      Marvel Comics          -      good   441.0  ...
# 1     191.0  Dark Horse Comics       blue      good    65.0  ...
# 2     185.0          DC Comics        red      good    90.0  ...
# 3     203.0      Marvel Comics          -       bad   441.0  ...
# 5     193.0      Marvel Comics          -       bad   122.0  ...
# ..      ...                ...        ...       ...     ...  ...
# 642   165.0      Marvel Comics          -      good    52.0  ...
# 643   304.8      Marvel Comics      white      good   -99.0  ...
# 644    66.0       George Lucas      green      good    17.0  ...
# 645   170.0          DC Comics          -      good    57.0  ...
# 646   185.0          DC Comics          -       bad    81.0  ...
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 5              False       False             False        False
# ..               ...         ...               ...          ...
# 642            False       False             False        False
# 643            False       False             False        False
# 644            False       False             False        False
# 645            False       False             False        False
# 646            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 5            False                  False          False        False
# ..             ...                    ...            ...          ...
# 642          False                  False          False        False
# 643          False                  False          False        False
# 644          False                  False          False        False
# 645          False                  False          False        False
# 646          False                  False          False        False
#
#      Omniscient  Power Count
# 0         False            7
# 1         False           16
# 2         False            1
# 3         False            8
# 5         False           11
# ..          ...          ...
# 642       False            3
# 643       False            6
# 644       False           19
# 645       False            8
# 646       False            4
#
# [484 rows x 178 columns]

# %% [markdown]
# ### Answering the Question, Again
#
# Now we can redo that plot without those negative heights:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(x=question_2_df["Height"], y=question_2_df["Power Count"], alpha=0.3)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Ok, that makes more sense. It looks like there is not much of a relationship between height and number of superpowers.
#
# Now we can go on to answering the second half of question 2: *And does this differ based on gender?*
#
# To indicate multiple categories within a scatter plot, we can use color to add a third dimension:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

# Select subsets
question_2_male = question_2_df[question_2_df["Gender"] == "Male"]
question_2_female = question_2_df[question_2_df["Gender"] == "Female"]
question_2_other = question_2_df[
    (question_2_df["Gender"] != "Male") & (question_2_df["Gender"] != "Female")
]

# Plot data with different colors
ax.scatter(
    x=question_2_male["Height"],
    y=question_2_male["Power Count"],
    alpha=0.5,
    color="cyan",
    label="Male",
)
ax.scatter(
    x=question_2_female["Height"],
    y=question_2_female["Power Count"],
    alpha=0.5,
    color="gray",
    label="Female",
)
ax.scatter(
    x=question_2_other["Height"],
    y=question_2_other["Power Count"],
    alpha=0.5,
    color="yellow",
    label="Other",
)

# Customize appearance
ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count")
ax.legend();

# %% [markdown]
# It appears that there is still no clear relationship between count of powers and height, regardless of gender. We do however note that "Male" is the most common gender, and that male superheroes tend to be taller, on average.

# %% [markdown]
# ## 4. Perform Data Aggregation Required to Answer Third Question
#
# Recall that the third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# We'll need to keep using `heroes_and_powers_df` since we require information from both `heroes_df` and `powers_df`.
#
# Your resulting `question_3_df` should contain aggregated data, with columns `Superpower Name`, `Marvel Comics` (containing the count of occurrences in Marvel Comics), and `DC Comics` (containing the count of occurrences in DC Comics). Each row should represent a superpower.
#
# In other words, `question_3_df` should look like this:
#
# ![question 3 df](images/question_3.png)
#
# Don't worry if the rows or columns are in a different order, all that matters is that you have the right rows and columns with all the data.
#
# ***Hint:*** refer to the [documentation for `.groupby`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html) and treat each publisher as a group.

# %%
# Your code here (create more cells as needed)
questions_3_df = heroes_and_powers_df.copy()

# %%
questions_3_df = questions_3_df[(questions_3_df['Publisher'] == "Marvel Comics") | (questions_3_df['Publisher'] == "DC Comics")]

# %%
questions_3_df['Publisher'].value_counts()
# Out:
# Marvel Comics    341
# DC Comics        196
# Name: Publisher, dtype: int64

# %%
cols_needed = list(powers_df.index)
cols_needed.append("Publisher")
questions_3_df = questions_3_df[cols_needed]
questions_3_df
# Out:
#      Agility  Accelerated Healing  Lantern Power Ring  Dimensional Awareness  \
# 0      False                 True               False                  False
# 2      False                False                True                  False
# 3      False                 True               False                  False
# 4      False                False               False                   True
# 5      False                False               False                  False
# ..       ...                  ...                 ...                    ...
# 641    False                False               False                  False
# 642    False                False               False                  False
# 643    False                False               False                  False
# 645    False                False               False                  False
# 646    False                False               False                  False
#
#      Cold Resistance  Durability  Stealth  Energy Absorption  Flight  \
# 0              False        True    False              False   False
# 2              False       False    False              False   False
# 3              False       False    False              False   False
# 4              False       False    False              False    True
# 5               True        True    False               True   False
# ..               ...         ...      ...                ...     ...
# 641            False       False    False              False   False
# 642            False       False    False              False    True
# 643             True        True    False              False   False
# 645            False       False    False              False   False
# 646            False       False    False              False   False
#
#      Danger Sense  ...  Reality Warping  Odin Force  Symbiote Costume  \
# 0           False  ...            False       False             False
# 2           False  ...            False       False             False
# 3           False  ...            False       False             False
# 4           False  ...            False       False             False
# 5           False  ...            False       False             False
# ..            ...  ...              ...         ...               ...
# 641         False  ...            False       False             False
# 642         False  ...            False       False             False
# 643         False  ...            False       False             False
# 645         False  ...            False       False             False
# 646         False  ...            False       False             False
#
#      Speed Force  Phoenix Force  Molecular Dissipation  Vision - Cryo  \
# 0          False          False                  False          False
# 2          False          False                  False          False
# 3          False          False                  False          False
# 4          False          False                  False          False
# 5          False          False                  False          False
# ..           ...            ...                    ...            ...
# 641        False          False                  False          False
# 642        False          False                  False          False
# 643        False          False                  False          False
# 645        False          False                  False          False
# 646        False          False                  False          False
#
#      Omnipresent  Omniscient      Publisher
# 0          False       False  Marvel Comics
# 2          False       False      DC Comics
# 3          False       False  Marvel Comics
# 4          False       False  Marvel Comics
# 5          False       False  Marvel Comics
# ..           ...         ...            ...
# 641        False       False  Marvel Comics
# 642        False       False  Marvel Comics
# 643        False       False  Marvel Comics
# 645        False       False      DC Comics
# 646        False       False      DC Comics
#
# [537 rows x 168 columns]

# %%
questions_3_df = questions_3_df.groupby(questions_3_df['Publisher']).sum()

# %%
questions_3_df.head()
# Out:
#                Agility  Accelerated Healing  Lantern Power Ring  \
# Publisher
# DC Comics           71                   51                  11
# Marvel Comics      126                  100                   0
#
#                Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# Publisher
# DC Comics                          7               15          71       48
# Marvel Comics                     16               25         154       47
#
#                Energy Absorption  Flight  Danger Sense  ...  Web Creation  \
# Publisher                                               ...
# DC Comics                     30      86             3  ...             0
# Marvel Comics                 43     111            20  ...            16
#
#                Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# Publisher
# DC Comics                    3           0                 1            1
# Marvel Comics                8           2                 8            0
#
#                Phoenix Force  Molecular Dissipation  Vision - Cryo  \
# Publisher
# DC Comics                  0                      1              1
# Marvel Comics              1                      0              0
#
#                Omnipresent  Omniscient
# Publisher
# DC Comics                0           0
# Marvel Comics            1           1
#
# [2 rows x 167 columns]

# %%
questions_3_df = questions_3_df.T

# %%
questions_3_df
# Out:
# Publisher              DC Comics  Marvel Comics
# Agility                       71            126
# Accelerated Healing           51            100
# Lantern Power Ring            11              0
# Dimensional Awareness          7             16
# Cold Resistance               15             25
# ...                          ...            ...
# Phoenix Force                  0              1
# Molecular Dissipation          1              0
# Vision - Cryo                  1              0
# Omnipresent                    0              1
# Omniscient                     0              1
#
# [167 rows x 2 columns]

# %%
questions_3_df.index.name = 'Superpower Name'

# %%
questions_3_df
# Out:
# Publisher              DC Comics  Marvel Comics
# Superpower Name
# Agility                       71            126
# Accelerated Healing           51            100
# Lantern Power Ring            11              0
# Dimensional Awareness          7             16
# Cold Resistance               15             25
# ...                          ...            ...
# Phoenix Force                  0              1
# Molecular Dissipation          1              0
# Vision - Cryo                  1              0
# Omnipresent                    0              1
# Omniscient                     0              1
#
# [167 rows x 2 columns]

# %%
questions_3_df.reset_index(inplace=True)

# %%
questions_3_df
# Out:
# Publisher        Superpower Name  DC Comics  Marvel Comics
# 0                        Agility         71            126
# 1            Accelerated Healing         51            100
# 2             Lantern Power Ring         11              0
# 3          Dimensional Awareness          7             16
# 4                Cold Resistance         15             25
# ..                           ...        ...            ...
# 162                Phoenix Force          0              1
# 163        Molecular Dissipation          1              0
# 164                Vision - Cryo          1              0
# 165                  Omnipresent          0              1
# 166                   Omniscient          0              1
#
# [167 rows x 3 columns]

# %%
questions_3_df.columns.name = None

# %%
questions_3_df
# Out:
#            Superpower Name  DC Comics  Marvel Comics
# 0                  Agility         71            126
# 1      Accelerated Healing         51            100
# 2       Lantern Power Ring         11              0
# 3    Dimensional Awareness          7             16
# 4          Cold Resistance         15             25
# ..                     ...        ...            ...
# 162          Phoenix Force          0              1
# 163  Molecular Dissipation          1              0
# 164          Vision - Cryo          1              0
# 165            Omnipresent          0              1
# 166             Omniscient          0              1
#
# [167 rows x 3 columns]

# %% [markdown]
# The code below checks that you have the correct dataframe structure:

# %%
# Run this cell without changes

# Checking that you made a dataframe called question_3_df
assert type(questions_3_df) == pd.DataFrame

# Checking the shape
assert questions_3_df.shape == (167, 3)

# Checking the column names
assert sorted(list(questions_3_df.columns)) == [
    "DC Comics",
    "Marvel Comics",
    "Superpower Name",
]

# %% [markdown]
# ### Answering the Question
#
# The code below uses the dataframe you created to find and plot the most common superpowers in Marvel Comics and DC Comics.

# %%
# Run this cell without changes

marvel_most_common = questions_3_df.drop("DC Comics", axis=1)
marvel_most_common = marvel_most_common.sort_values(
    by="Marvel Comics", ascending=False
)[:5]
marvel_most_common
# Out:
#    Superpower Name  Marvel Comics
# 17  Super Strength            204
# 5       Durability            154
# 25         Stamina            150
# 30     Super Speed            137
# 0          Agility            126

# %%
# Run this cell without changes

dc_most_common = questions_3_df.drop("Marvel Comics", axis=1)
dc_most_common = dc_most_common.sort_values(by="DC Comics", ascending=False)[:5]
dc_most_common
# Out:
#    Superpower Name  DC Comics
# 17  Super Strength        109
# 25         Stamina         90
# 8           Flight         86
# 30     Super Speed         79
# 5       Durability         71

# %%
# Run this cell without changes

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 5))

ax1.bar(
    x=marvel_most_common["Superpower Name"], height=marvel_most_common["Marvel Comics"]
)
ax2.bar(x=dc_most_common["Superpower Name"], height=dc_most_common["DC Comics"])

ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Frequency of Top Superpowers in Marvel Comics")
ax2.set_title("Frequency of Top Superpowers in DC Comics");

# %% [markdown]
# It looks like super strength is the most popular power in both Marvel Comics and DC Comics. Overall, the top 5 powers are fairly similar — 4 out of 5 overlap, although Marvel contains agility whereas DC contains flight.

# %% [markdown]
# ## 5. Formulate and Answer Your Own Question
#
# For the remainder of this lab, you'll be focusing on coming up with and answering your own question, just like we did above.  Your question should not be overly simple, and should require both descriptive statistics and data visualization to answer.  In case you're unsure of what questions to ask, some sample questions have been provided below.
#
# Pick one of the following questions to investigate and answer, or come up with one of your own!
#
# * Which powers have the highest chance of co-occurring in a hero (e.g. super strength and flight)?
# * What is the distribution of skin colors amongst alien heroes?
# * How are eye color and hair color related in this dataset?
#
# Explain your question below:

# %%
# Replace None with appropriate text:
"""
I want to look at the Top Ten superheroes based on the most superpowers and compare their weights for 
both the males and females to see if there is any relationship. I will use the heroes_and_powers_df to do so. 
"""
# Out:
# '\nI want to look at the top ten superheroes based on the most superpowers and compare their heights and weights for \nboth the males and females to see if there is any relationship. I will use the heroes_and_powers_df to do so. \n'

# %% [markdown]
# Some sample cells have been provided to give you room to work. Feel free to create more cells as needed.
#
# Be sure to include thoughtful, well-labeled visualizations to back up your analysis!
#
# (There is no solution branch for this part, and feel free to move on to the next lesson if you have already spent more than 90 minutes.)

# %%
heroes_and_powers_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 642  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 643             Ymir    Male     white        Frost Giant           No Hair
# 644             Yoda    Male     brown     Yoda's species             White
# 645          Zatanna  Female      blue              Human             Black
# 646             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  ...  \
# 0     203.0      Marvel Comics          -      good   441.0  ...
# 1     191.0  Dark Horse Comics       blue      good    65.0  ...
# 2     185.0          DC Comics        red      good    90.0  ...
# 3     203.0      Marvel Comics          -       bad   441.0  ...
# 4     -99.0      Marvel Comics          -       bad   -99.0  ...
# ..      ...                ...        ...       ...     ...  ...
# 642   165.0      Marvel Comics          -      good    52.0  ...
# 643   304.8      Marvel Comics      white      good   -99.0  ...
# 644    66.0       George Lucas      green      good    17.0  ...
# 645   170.0          DC Comics          -      good    57.0  ...
# 646   185.0          DC Comics          -       bad    81.0  ...
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 4              False       False             False        False
# ..               ...         ...               ...          ...
# 642            False       False             False        False
# 643            False       False             False        False
# 644            False       False             False        False
# 645            False       False             False        False
# 646            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# ..             ...                    ...            ...          ...
# 642          False                  False          False        False
# 643          False                  False          False        False
# 644          False                  False          False        False
# 645          False                  False          False        False
# 646          False                  False          False        False
#
#      Omniscient  Power Count
# 0         False            7
# 1         False           16
# 2         False            1
# 3         False            8
# 4         False           14
# ..          ...          ...
# 642       False            3
# 643       False            6
# 644       False           19
# 645       False            8
# 646       False            4
#
# [647 rows x 178 columns]

# %%
Heros_and_powers_hs_ws_df = heroes_and_powers_df.copy()

# %%
Heros_and_powers_hs_ws_df = heroes_and_powers_df[['name', 'Gender','Power Count', 'Weight']]

# %%
Heros_and_powers_hs_ws_df
# Out:
#                 name  Gender  Power Count  Weight
# 0             A-Bomb    Male            7   441.0
# 1         Abe Sapien    Male           16    65.0
# 2           Abin Sur    Male            1    90.0
# 3        Abomination    Male            8   441.0
# 4            Abraxas    Male           14   -99.0
# ..               ...     ...          ...     ...
# 642  Yellowjacket II  Female            3    52.0
# 643             Ymir    Male            6   -99.0
# 644             Yoda    Male           19    17.0
# 645          Zatanna  Female            8    57.0
# 646             Zoom    Male            4    81.0
#
# [647 rows x 4 columns]

# %%
Heros_and_powers_male = Heros_and_powers_hs_ws_df[Heros_and_powers_hs_ws_df['Gender']=='Male']
Heros_and_powers_male = Heros_and_powers_male[Heros_and_powers_male['Weight'] != -99.0]

Heros_and_powers_male = Heros_and_powers_male.sort_values(by='Power Count', ascending=False)[:10]
Heros_and_powers_male
# Out:
#                   name Gender  Power Count  Weight
# 17               Amazo   Male           44   173.0
# 377  Martian Manhunter   Male           35   135.0
# 139     Captain Marvel   Male           33   101.0
# 576             T-1000   Male           32   146.0
# 239           Galactus   Male           32    16.0
# 437               Odin   Male           31   293.0
# 582             Thanos   Male           31   443.0
# 128              Cable   Male           30   158.0
# 571           Superman   Male           29   101.0
# 236  Franklin Richards   Male           29    45.0

# %%
Heros_and_powers_female = Heros_and_powers_hs_ws_df[Heros_and_powers_hs_ws_df['Gender']=='Female']
Heros_and_powers_female = Heros_and_powers_female[Heros_and_powers_female['Weight'] != -99.0]
Heros_and_powers_female = Heros_and_powers_female.sort_values(by='Power Count', ascending=False)[:10]
Heros_and_powers_female
# Out:
#                name  Gender  Power Count  Weight
# 579             T-X  Female           33   149.0
# 138  Captain Marvel  Female           33    74.0
# 638    Wonder Woman  Female           30    74.0
# 570       Supergirl  Female           27    54.0
# 459      Power Girl  Female           24    81.0
# 436            Nova  Female           24    59.0
# 453         Phoenix  Female           18    52.0
# 154     Cheetah III  Female           18    54.0
# 621           Vixen  Female           17    63.0
# 39           Ardina  Female           17    98.0

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize = (15,5))

ax1.bar(x=Heros_and_powers_male['name'], height=Heros_and_powers_male['Weight'])

ax2.bar(x=Heros_and_powers_female['name'], height=Heros_and_powers_female['Weight'])

ax1.set_xlabel("Superheroes")
ax2.set_xlabel("Superheroes")

ax1.set_xticklabels(Heros_and_powers_male['name'], rotation=55)
ax2.set_xticklabels(Heros_and_powers_female['name'], rotation=55)

ax1.set_ylabel("Superheroes Weights")
ax2.set_ylabel("Superheroes Weight")

ax1.set_title("Top Ten Male Superheroes")
ax2.set_title("Top Ten Female Superheroes")


;
# Out:
# <ipython-input-103-7de25488105f>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(Heros_and_powers_male['name'], rotation=55)
# <ipython-input-103-7de25488105f>:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(Heros_and_powers_female['name'], rotation=55)
# ''

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize = (15,5))

ax1.bar(x=Heros_and_powers_male['name'], height=Heros_and_powers_male['Power Count'])

ax2.bar(x=Heros_and_powers_female['name'], height=Heros_and_powers_female['Power Count'])

ax1.set_xlabel("Superheroes")
ax2.set_xlabel("Superheroes")

ax1.set_xticklabels(Heros_and_powers_male['name'], rotation=55)
ax2.set_xticklabels(Heros_and_powers_female['name'], rotation=55)

ax1.set_ylabel("Superheroes Power Count")
ax2.set_ylabel("Superheroes Power Count")

ax1.set_title("Top Ten Male Superheroes")
ax2.set_title("Top Ten Female Superheroes")


;
# Out:
# <ipython-input-90-56b09a330b5e>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(Heros_and_powers_male['name'], rotation=55)
# <ipython-input-90-56b09a330b5e>:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(Heros_and_powers_female['name'], rotation=55)
# ''

# %% [markdown]
# After some exploratory data analysis, it appears for the top ten superheroes based on power count, there is no relationship with their weight for the males or the females. The higher the power count does not mean that the superhero will weigh more, regardless if they are male or female.

# %% [markdown]
# ## Summary
#
# In this lab, you demonstrated your mastery of using pandas to clean and aggregate data in order to answer several business questions. This included identifying and handling missing values, text requiring preprocessing, and invalid values. You also performed aggregation and reshaping tasks such as transposing, joining, and grouping data. Great job, there was a lot here!
